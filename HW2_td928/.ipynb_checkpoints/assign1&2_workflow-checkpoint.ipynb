# %%
from __future__ import print_function
import pylab as pl
import os
import json
import sys
import pandas as pd
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib

# %pylab inline
pl.rc('font', size = 15)

my_key = '9bd59b7e-d0f9-4358-818a-ab5abd8ac26f'
print (my_key)

url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=" + my_key + "&VehicleMonitoringDetailLevel=calls&LineRef=B52"
print (url)
response = urllib.urlopen(url)
data = response.read().decode("utf-8")
data = json.loads(data)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 9bd59b7e-d0f9-4358-818a-ab5abd8ac26f
# http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=9bd59b7e-d0f9-4358-818a-ab5abd8ac26f&VehicleMonitoringDetailLevel=calls&LineRef=B52

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# [u'Siri']

# %%
data['Siri']
# Out:
# {u'ServiceDelivery': {u'ResponseTimestamp': u'2017-09-22T14:51:35.169-04:00',
#   u'SituationExchangeDelivery': [],
#   u'VehicleMonitoringDelivery': [{u'ResponseTimestamp': u'2017-09-22T14:51:35.169-04:00',
#     u'ValidUntil': u'2017-09-22T14:52:35.169-04:00',
#     u'VehicleActivity': [{u'MonitoredVehicleJourney': {u'Bearing': 186.49905,
#        u'BlockRef': u'MTA NYCT_FP_D7-Weekday_C_FP_28440_B54-212',
#        u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#        u'DestinationRef': u'MTA_901463',
#        u'DirectionRef': u'1',
#        u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-22',
#         u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-085800_B52_118'},
#        u'JourneyPatternRef': u'MTA_B520048',
#        u'LineRef': u'MTA NYCT_B52',
#        u'Monitored': True,
#        u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-22T14:51:36.169-04:00',
#         u'ExpectedDepartureTime': u'2017-09-22T14:51:36.169-04:00',
# ...

# %%
data['Siri'].keys()
# Out:
# [u'ServiceDelivery']

# %%
data['Siri']['ServiceDelivery']
# Out:
# {u'ResponseTimestamp': u'2017-09-22T14:51:35.169-04:00',
#  u'SituationExchangeDelivery': [],
#  u'VehicleMonitoringDelivery': [{u'ResponseTimestamp': u'2017-09-22T14:51:35.169-04:00',
#    u'ValidUntil': u'2017-09-22T14:52:35.169-04:00',
#    u'VehicleActivity': [{u'MonitoredVehicleJourney': {u'Bearing': 186.49905,
#       u'BlockRef': u'MTA NYCT_FP_D7-Weekday_C_FP_28440_B54-212',
#       u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#       u'DestinationRef': u'MTA_901463',
#       u'DirectionRef': u'1',
#       u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-22',
#        u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-085800_B52_118'},
#       u'JourneyPatternRef': u'MTA_B520048',
#       u'LineRef': u'MTA NYCT_B52',
#       u'Monitored': True,
#       u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-22T14:51:36.169-04:00',
#        u'ExpectedDepartureTime': u'2017-09-22T14:51:36.169-04:00',
# ...

# %%
data['Siri']['ServiceDelivery'].keys()
# Out:
# [u'SituationExchangeDelivery',
#  u'ResponseTimestamp',
#  u'VehicleMonitoringDelivery']

# %%
len(data['Siri']['ServiceDelivery']['SituationExchangeDelivery'])
# Out:
# 1

# %%
data['Siri']['ServiceDelivery']['ResponseTimestamp']
# Out:
# u'2017-09-22T16:50:38.825-04:00'

# %%
data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0].keys()
# Out:
# [u'VehicleActivity', u'ValidUntil', u'ResponseTimestamp']

# %%
data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity']
# Out:
# [{u'MonitoredVehicleJourney': {u'Bearing': 186.49905,
#    u'BlockRef': u'MTA NYCT_FP_D7-Weekday_C_FP_28440_B54-212',
#    u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#    u'DestinationRef': u'MTA_901463',
#    u'DirectionRef': u'1',
#    u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-22',
#     u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-085800_B52_118'},
#    u'JourneyPatternRef': u'MTA_B520048',
#    u'LineRef': u'MTA NYCT_B52',
#    u'Monitored': True,
#    u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-22T14:51:36.169-04:00',
#     u'ExpectedDepartureTime': u'2017-09-22T14:51:36.169-04:00',
#     u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2430.58,
#       u'DistanceFromCall': 0.0,
#       u'PresentableDistance': u'at stop',
#       u'StopsFromCall': 0}},
#     u'StopPointName': u'GATES AV/MALCOLM X BL',
#     u'StopPointRef': u'MTA_304205',
#     u'VisitNumber': 1},
# ...

# %%
len(data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'])
# Out:
# 14

# %%
data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][6]
# Out:
# {u'MonitoredVehicleJourney': {u'Bearing': 186.58632,
#   u'BlockRef': u'MTA NYCT_FP_D7-Weekday_C_FP_27240_B52-124',
#   u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#   u'DestinationRef': u'MTA_901463',
#   u'DirectionRef': u'1',
#   u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-22',
#    u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-083800_B52_114'},
#   u'JourneyPatternRef': u'MTA_B520048',
#   u'LineRef': u'MTA NYCT_B52',
#   u'Monitored': True,
#   u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-22T14:51:51.316-04:00',
#    u'ExpectedDepartureTime': u'2017-09-22T14:51:51.316-04:00',
#    u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5908.9,
#      u'DistanceFromCall': 53.55,
#      u'PresentableDistance': u'approaching',
#      u'StopsFromCall': 0}},
#    u'StopPointName': u'GREENE AV/VANDERBILT AV',
#    u'StopPointRef': u'MTA_307575',
#    u'VisitNumber': 1},
# ...

# %%
u'VehicleLocation': {u'Latitude': 40.687296, u'Longitude': -73.976882},
    u'VehicleLocation': {u'Latitude': 40.686758, u'Longitude': -73.965402},
        u'VehicleLocation': {u'Latitude': 40.686424, u'Longitude': -73.968303},
# Out:
#   File "<ipython-input-39-8860c811e359>", line 1
#     u'VehicleLocation': {u'Latitude': 40.687296, u'Longitude': -73.976882},
#                       ^
# SyntaxError: invalid syntax

# %%
data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][1]
# Out:
# {u'MonitoredVehicleJourney': {u'Bearing': 6.4588165,
#   u'BlockRef': u'MTA NYCT_FP_D7-Weekday_C_FP_24540_B52-114',
#   u'DestinationName': u'RIDGEWOOD TERM via GATES',
#   u'DestinationRef': u'MTA_801117',
#   u'DirectionRef': u'0',
#   u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-22',
#    u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-085700_B52_109'},
#   u'JourneyPatternRef': u'MTA_B520040',
#   u'LineRef': u'MTA NYCT_B52',
#   u'Monitored': True,
#   u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-22T14:51:36.169-04:00',
#    u'ExpectedDepartureTime': u'2017-09-22T14:51:36.169-04:00',
#    u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 5826.46,
#      u'DistanceFromCall': 10.82,
#      u'PresentableDistance': u'at stop',
#      u'StopsFromCall': 0}},
#    u'StopPointName': u'GATES AV/STUYVESANT AV',
#    u'StopPointRef': u'MTA_307682',
#    u'VisitNumber': 1},
# ...

# %%
data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0].keys()
# Out:
# [u'RecordedAtTime', u'MonitoredVehicleJourney']

# %%
data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']
# Out:
# {u'Bearing': 186.49905,
#  u'BlockRef': u'MTA NYCT_FP_D7-Weekday_C_FP_28440_B54-212',
#  u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#  u'DestinationRef': u'MTA_901463',
#  u'DirectionRef': u'1',
#  u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-22',
#   u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-085800_B52_118'},
#  u'JourneyPatternRef': u'MTA_B520048',
#  u'LineRef': u'MTA NYCT_B52',
#  u'Monitored': True,
#  u'MonitoredCall': {u'ExpectedArrivalTime': u'2017-09-22T14:51:36.169-04:00',
#   u'ExpectedDepartureTime': u'2017-09-22T14:51:36.169-04:00',
#   u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 2430.58,
#     u'DistanceFromCall': 0.0,
#     u'PresentableDistance': u'at stop',
#     u'StopsFromCall': 0}},
#   u'StopPointName': u'GATES AV/MALCOLM X BL',
#   u'StopPointRef': u'MTA_304205',
#   u'VisitNumber': 1},
#  u'OnwardCalls': {u'OnwardCall': [{u'ExpectedArrivalTime': u'2017-09-22T14:51:35.169-04:00',
# ...

# %%
data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney'].keys()
# Out:
# [u'OriginRef',
#  u'Bearing',
#  u'VehicleLocation',
#  u'SituationRef',
#  u'OperatorRef',
#  u'VehicleRef',
#  u'BlockRef',
#  u'DestinationName',
#  u'DestinationRef',
#  u'JourneyPatternRef',
#  u'MonitoredCall',
#  u'LineRef',
#  u'FramedVehicleJourneyRef',
#  u'PublishedLineName',
#  u'Monitored',
#  u'OnwardCalls',
#  u'DirectionRef',
#  u'ProgressRate']

# %%
data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']['VehicleLocation']
# Out:
# {u'Latitude': 40.688515, u'Longitude': -73.930609}

# %%
data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]
['MonitoredVehicleJourney'](2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-fb7fcc880e0e> in <module>()
#       1 data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]
# ----> 2 ['MonitoredVehicleJourney'](2)
#
# TypeError: 'list' object is not callable

# %%
data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']['VehicleLocation'].keys()
# Out:
# [u'Latitude', u'Longitude']

# %%
location = data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity'][0]['MonitoredVehicleJourney']['VehicleLocation']

# %%
type(location)
# Out:
# dict

# %%
for key in location:
    print(key,location[key])
# Out:
# Latitude 40.688515
# Longitude -73.930609

# %%
all_vehicles_info = data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity']

vehicle_count = len(all_vehicles_info)
for i in range(vehicle_count):
    location = all_vehicles_info[i]['MonitoredVehicleJourney']['VehicleLocation']
    keys = location.keys()
    print ('Bus ' + str(i) + ' is at latitude ' + str(location[keys[0]]) + ' and longitude ' + str(location[keys[1]]))
# Out:
# Bus 0 is at latitude 40.695161 and longitude -73.916501
# Bus 1 is at latitude 40.687513 and longitude -73.939316
# Bus 2 is at latitude 40.688569 and longitude -73.980088
# Bus 3 is at latitude 40.68792 and longitude -73.935776
# Bus 4 is at latitude 40.68854 and longitude -73.980014
# Bus 5 is at latitude 40.68753 and longitude -73.939177
# Bus 6 is at latitude 40.690799 and longitude -73.985701
# Bus 7 is at latitude 40.686171 and longitude -73.970492
# Bus 8 is at latitude 40.691022 and longitude -73.920565
# Bus 9 is at latitude 40.686883 and longitude -73.944795
# Bus 10 is at latitude 40.685744 and longitude -73.954694
# Bus 11 is at latitude 40.686118 and longitude -73.97396
# Bus 12 is at latitude 40.685645 and longitude -73.955543
# Bus 13 is at latitude 40.700599 and longitude -73.909948

# %%
all_vehicles_info[0]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall']
# Out:
# [{u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 918.53,
#     u'DistanceFromCall': 2.25,
#     u'PresentableDistance': u'at stop',
#     u'StopsFromCall': 0}},
#   u'StopPointName': u'GATES AV/WILSON AV',
#   u'StopPointRef': u'MTA_304198'},
#  {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1127.58,
#     u'DistanceFromCall': 211.3,
#     u'PresentableDistance': u'1 stop away',
#     u'StopsFromCall': 1}},
#   u'StopPointName': u'GATES AV/CENTRAL AV',
#   u'StopPointRef': u'MTA_304199'},
#  {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1369.74,
#     u'DistanceFromCall': 453.47,
#     u'PresentableDistance': u'2 stops away',
#     u'StopsFromCall': 2}},
#   u'StopPointName': u'GATES AV/EVERGREEN AV',
#   u'StopPointRef': u'MTA_304200'},
#  {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 1539.93,
#     u'DistanceFromCall': 623.65,
#     u'PresentableDistance': u'3 stops away',
#     u'StopsFromCall': 3}},
# ...

# %%
len(all_vehicles_info[0]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'])
# Out:
# 33

# %%
all_vehicles_info[0]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]
# Out:
# {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 918.53,
#    u'DistanceFromCall': 2.25,
#    u'PresentableDistance': u'at stop',
#    u'StopsFromCall': 0}},
#  u'StopPointName': u'GATES AV/WILSON AV',
#  u'StopPointRef': u'MTA_304198'}

# %%
all_vehicles_info[0]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0].keys()
# Out:
# [u'StopPointRef', u'StopPointName', u'Extensions']

# %%
all_vehicles_info
# Out:
# [{u'MonitoredVehicleJourney': {u'Bearing': 225.55896,
#    u'BlockRef': u'MTA NYCT_FP_D7-Weekday_C_FP_59460_B52-137',
#    u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES',
#    u'DestinationRef': u'MTA_901463',
#    u'DirectionRef': u'1',
#    u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-22',
#     u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-100300_B52_137'},
#    u'JourneyPatternRef': u'MTA_B520048',
#    u'LineRef': u'MTA NYCT_B52',
#    u'Monitored': True,
#    u'MonitoredCall': {u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 918.53,
#       u'DistanceFromCall': 2.25,
#       u'PresentableDistance': u'at stop',
#       u'StopsFromCall': 0}},
#     u'StopPointName': u'GATES AV/WILSON AV',
#     u'StopPointRef': u'MTA_304198',
#     u'VisitNumber': 1},
#    u'OnwardCalls': {u'OnwardCall': [{u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 918.53,
#         u'DistanceFromCall': 2.25,
#         u'PresentableDistance': u'at stop',
# ...

# %%
for i in range(vehicle_count):
    print(all_vehicles_info[i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['StopPointName'])
# Out:
# GATES AV/WILSON AV
# GATES AV/MARCUS GARVEY BL
# FULTON ST/HUDSON AV
# GATES AV/LEWIS AV
# FULTON ST/HUDSON AV
# GATES AV/MARCUS GARVEY BL
# FULTON ST/HOYT ST
# GREENE AV/ADELPHI ST
# GATES AV/BUSHWICK AV
# GATES AV/TOMPKINS AV
# GATES AV/BEDFORD AV
# GREENE AV/FULTON ST
# GATES AV/BEDFORD AV
# GATES AV/WYCKOFF AV

# %%
OnwardCall = all_vehicles_info[0]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall']

# %%
OnwardCall[0]['Extensions']['Distances']['PresentableDistance']
# Out:
# u'at stop'

# %%
for i in range(vehicle_count):
    print(all_vehicles_info[i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall'][0]['StopPointName'])
    OnwardCall = all_vehicles_info[i]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall']
    print(OnwardCall[0]['Extensions']['Distances']['PresentableDistance'])

# %%
import csv

# %%
    try: 
        OnwardCall = all_vehicles_info[0]['MonitoredVehicleJourney']['OnwardCalls']['OnwardCall']
        stop_name = OnwardCall[0]['StopPointName']
        stop_status = OnwardCall[0]['Extensions']['Distances']['PresentableDistance']
    except KeyError:
        stop_name = 'N/A'
        stop_status = 'N/A'
    
    
    # Getting the coordinate of the buses
    
    location = all_vehicles_info[0]['MonitoredVehicleJourney']['VehicleLocation']
    latitude = location['Latitude']
    longitude = location['Longitude']
    
    # Creating a panda series to store the new values and update the dataframe
    
    ob = pd.Series([latitude, longitude, stop_name, stop_status], index = ['Latitude', 'Longitude', 'Stop Name', 'Stop Status'])

# %%
ob
# Out:
# Latitude                  40.6952
# Longitude                -73.9165
# Stop Name      GATES AV/WILSON AV
# Stop Status               at stop
# dtype: object

# %%
stop_info_dict = {}

# %%
stop_infor_dict = {'1': }
