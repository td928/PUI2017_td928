# %%
from __future__ import print_function
import numpy as np
from pandas import Series, DataFrame
import pandas
import pandas as pd
import pylab as py

# %pylab inline

import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
PUIdata = os.getenv('DFDATA')

print (PUIdata)
# Out:
# /gws/open/NYCOpenData/nycopendata/data

# %%
df_collisions = pd.read_csv(PUIdata + '/h9gi-nx95/1428430582/h9gi-nx95')

df_collisions
# Out:
#               DATE   TIME        BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0       04/04/2015   9:25      MANHATTAN   10001.0  40.750788 -74.005630
# 1       04/04/2015  21:15         QUEENS   11357.0  40.781291 -73.814200
# 2       04/04/2015  16:52         QUEENS   11385.0  40.702595 -73.855293
# 3       04/04/2015   9:30      MANHATTAN   10025.0  40.804886 -73.962474
# 4       04/04/2015   9:41         QUEENS   11428.0  40.715144 -73.749356
# 5       04/04/2015   9:45       BROOKLYN   11217.0  40.687945 -73.981401
# 6       04/04/2015   9:45         QUEENS   11354.0  40.766886 -73.823951
# 7       04/04/2015   9:50            NaN       NaN        NaN        NaN
# 8       04/04/2015  16:52       BROOKLYN   11219.0  40.626362 -74.008300
# 9       04/04/2015  13:00         QUEENS   11354.0  40.763942 -73.828146
# 10      04/04/2015   9:54      MANHATTAN   10065.0  40.769270 -73.969364
# 11      04/04/2015   9:55            NaN       NaN  40.749472 -73.756393
# ...

# %%
df_collisions.keys()
# Out:
# Index([u'PROGRAM_LST_ID', u'PROGRAM_CODE', u'PROGRAM_NAME', u'ACTIVE_FLAG',
#        u'AGENCY_NAME', u'DESCRIPTION', u'BOROUGH', u'PROG_CONTACT_LAST_NAME',
#        u'PROG_CONTACT_FIRST_NAME', u'PROG_CONTACT_PHONE_NO',
#        u'PROG_CONTACT_FAX_NO', u'PROG_CONTACT_EXTENSION',
#        u'PROG_CONTACT_EMAIL', u'PROGRAM_ADDRESS_1', u'PROGRAM_ADDRESS_2',
#        u'PROGRAM_CITY', u'PROGRAM_ZIP', u'OFFICE_MON_FROM_TIME',
#        u'OFFICE_MON_TO_TIME', u'OFFICE_TUES_FROM_TIME', u'OFFICE_TUES_TO_TIME',
#        u'OFFICE_WED_FROM_TIME', u'OFFICE_WED_TO_TIME',
#        u'OFFICE_THURS_FROM_TIME', u'OFFICE_THURS_TO_TIME',
#        u'OFFICE_FRI_FROM_TIME', u'OFFICE_FRI_TO_TIME', u'OFFICE_SAT_FROM_TIME',
#        u'OFFICE_SAT_TO_TIME', u'OFFICE_SUN_FROM_TIME', u'OFFICE_SUN_TO_TIME'],
#       dtype='object')
